# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('merged_data_1951_2021.csv')

# %%
df
# Out:
#              time  lon   lat       temp
# 0      1951-01-01   83  25.5  22.980000
# 1      1951-01-02   83  25.5  21.580000
# 2      1951-01-03   83  25.5  21.510000
# 3      1951-01-04   83  25.5  21.410000
# 4      1951-01-05   83  25.5  22.889999
# ...           ...  ...   ...        ...
# 25928  2021-12-27   83  25.5  24.007275
# 25929  2021-12-28   83  25.5  21.532618
# 25930  2021-12-29   83  25.5  18.243288
# 25931  2021-12-30   83  25.5  18.774710
# 25932  2021-12-31   83  25.5  18.886730
#
# [25933 rows x 4 columns]

# %%
sns.countplot(x=df['temp'])
# Out:
# <Axes: xlabel='temp', ylabel='count'>

# %%
correlation = df['lon'].corr(df['temp'])

print("Correlation coefficient between numerical_feature1 and numerical_feature2:", correlation)
# Out:
# Correlation coefficient between numerical_feature1 and numerical_feature2: nan
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
numeric_data = df.select_dtypes(include=['float64', 'int64'])

# %%
sns.heatmap(numeric_data.corr())
# Out:
# <Axes: >

# %%
sns.jointplot(x='temp',y='lon',data=df,kind='hex')
# Out:
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x='temp',y='lat',data=df,kind='hex')
# Out:
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df)
# Out:
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Brijesh kumar\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df.target_names
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19416\73343841.py in ?()
# ----> 1 df.target_names
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'target_names'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8),dpi=100)   #set the canvas size for visibility

plt.scatter(X.T[0],X.T[2])   #over here I use the T ndarray method to transpose the data then get columns at index 0 and 2
plt.title('IRIS Petal and sepal length', fontsize=20) # set the title of the plot and adjust my font size for readability

#then we set the label (just to be obvious)
plt.ylabel('temp') 
plt.xlabel('lon')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(18,8),dpi=100)   #set the canvas size for visibility
# ----> 4 plt.scatter(X.T[0],X.T[2])   #over here I use the T ndarray method to transpose the data then get columns at index 0 and 2
#       5 plt.title('IRIS Petal and sepal length', fontsize=20) # set the title of the plot and adjust my font size for readability
#       7 #then we set the label (just to be obvious)
#
# NameError: name 'X' is not defined
